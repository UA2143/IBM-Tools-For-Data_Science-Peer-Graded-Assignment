# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib

# %% [markdown]
# | **Tool**                    | **Purpose**                         | **Description**                                                                          |
# |-----------------------------|-------------------------------------|------------------------------------------------------------------------------------------|
# | **NumPy**                    | Numerical Computing                 | A library for numerical computations in Python, providing support for arrays and matrices.|
# | **Pandas**                   | Data Manipulation and Analysis      | A library offering data structures and functions designed to make data manipulation simple.|
# | **Matplotlib**               | Data Visualization                  | A plotting library used for creating static, animated, and interactive visualizations.     |
# | **Seaborn**                  | Statistical Data Visualization      | Built on top of Matplotlib, it provides a high-level interface for drawing attractive statistical graphics. |
# | **TensorFlow**               | Machine Learning                    | An open-source platform for machine learning, widely used for building and deploying ML models.|
# | **Keras**                    | Deep Learning                       | A user-friendly neural network library that runs on top of TensorFlow, simplifying the creation of deep learning models.|
# | **scikit-learn**             | Machine Learning                    | A library that offers simple and efficient tools for data mining and data analysis.       |
# | **OpenCV**                   | Computer Vision                     | A library designed to solve computer vision problems, enabling image and video processing.|
# | **XGBoost**                  | Gradient Boosting                   | An optimized distributed gradient boosting library designed to be highly efficient and flexible.|
# | **NLTK**                     | Natural Language Processing (NLP)   | A leading platform for building Python programs to work with human language data.         |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
a = (3 * 4) + 5
print(a)
# Out:
# 17

# %%
minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
#
# * List popular languages for Data Science.
# * List commonly used libraries in Data Science.
# * Demonstrate basic arithmetic operations in Python.

# %% [markdown]
# ## Author
#
# Uneeb
